# %%
import pandas as pd
df = pd.read_csv('./export2023.06.18-10.18.53.csv', index_col=0, parse_dates=True)

# %%
df
# Out:
#                                                                                               Authors  \
# Document Title
# Smartphone based experience sampling of stress-...  J. Weppner; P. Lukowicz; S. Serino; P. Cipress...
# Audioclip: Extending Clip to Image, Text and Audio             A. Guzhov; F. Raue; J. Hees; A. Dengel
# Comments on an optimal set of indices for a rel...                                 B. . -J. Falkowski
# SemAttNet: Toward Attention-Based Semantic Awar...  D. Nazir; A. Pagani; M. Liwicki; D. Stricker; ...
# Analysis of interventions to optimize a pumping...           M. Colombo; P. Jell; P. Theumer; A. Heim
# A Smart Integration Layer for Smart City Busine...                     D. Spieldenner; T. Spieldenner
# Modular augmented reality platform for smart op...                     J. Um; J. Popper; M. Ruskowski
# High-Quality Rendering of Quartic Spline Surfac...  G. Reis; F. Zeilfelder; M. Hering-Bertram; G. ...
# ...
